# %%
import pandas as pd
import numpy as np
import requests
import bs4 as bs
import urllib.request

# %% [markdown]
# ## Extracting features of 2020 movies from Wikipedia

# %%
link = "https://en.wikipedia.org/wiki/List_of_American_films_of_2020"

# %%
source = urllib.request.urlopen(link).read()
soup = bs.BeautifulSoup(source,'lxml')

# %%
tables = soup.find_all('table',class_='wikitable sortable')

# %%
len(tables)
# Out:
# 4

# %%
type(tables[0])
# Out:
# bs4.element.Tag

# %%
df1 = pd.read_html(str(tables[0]))[0]
df2 = pd.read_html(str(tables[1]))[0]
df3 = pd.read_html(str(tables[2]))[0]
df4 = pd.read_html(str(tables[3]).replace("'1\"\'",'"1"'))[0] # avoided "ValueError: invalid literal for int() with base 10: '1"'

# %%
df = df1.append(df2.append(df3.append(df4,ignore_index=True),ignore_index=True),ignore_index=True)

# %%
df
# Out:
#       Opening  Opening.1              Title  \
# 0     JANUARY        3.0         The Grudge
# 1     JANUARY       10.0         Underwater
# 2     JANUARY       10.0        Like a Boss
# 3     JANUARY       10.0  Inherit the Viper
# 4     JANUARY       10.0         The Sonata
# ..        ...        ...                ...
# 177  DECEMBER       18.0   Coming 2 America
# 178  DECEMBER       18.0         The Father
# 179  DECEMBER       25.0  Wonder Woman 1984
# 180  DECEMBER       25.0  News of the World
# 181  DECEMBER        NaN                NaN
#
#                                     Production company  \
# 0    Screen Gems / Stage 6 Films / Ghost House Pict...
# 1    20th Century Fox / TSG Entertainment / Chernin...
# 2                                   Paramount Pictures
# 3       Barry Films / Tycor International Film Company
# 4                                   Screen Media Films
# ..                                                 ...
# 177                                 Paramount Pictures
# 178                     Sony Pictures Classics / Film4
# 179  Warner Bros. Pictures / DC Films / The Stone Q...
# 180                                 Universal Pictures
# 181                                                NaN
#
#                                          Cast and crew   Ref.
# 0    Nicolas Pesce (director/screenplay); Andrea Ri...    [2]
# 1    William Eubank (director); Brian Duffield, Ada...    [3]
# 2    Miguel Arteta (director); Sam Pitman, Adam Col...    [4]
# 3    Anthony Jerjen (director); Andrew Crabtree (sc...    [5]
# 4    Andrew Desmond (director/screenplay); Arthur M...    [6]
# ..                                                 ...    ...
# 177  Craig Brewer (director); Kenya Barris, Barry W...  [173]
# 178  Florian Zeller (director/screenplay); Christop...    NaN
# 179  Patty Jenkins (director/screenplay); Geoff Joh...  [174]
# 180  Paul Greengrass (director/screenplay); Luke Da...  [175]
# 181                                                NaN    NaN
#
# [182 rows x 6 columns]

# %%
df_2020 = df[['Title','Cast and crew']]

# %%
df_2020
# Out:
#                  Title                                      Cast and crew
# 0           The Grudge  Nicolas Pesce (director/screenplay); Andrea Ri...
# 1           Underwater  William Eubank (director); Brian Duffield, Ada...
# 2          Like a Boss  Miguel Arteta (director); Sam Pitman, Adam Col...
# 3    Inherit the Viper  Anthony Jerjen (director); Andrew Crabtree (sc...
# 4           The Sonata  Andrew Desmond (director/screenplay); Arthur M...
# ..                 ...                                                ...
# 177   Coming 2 America  Craig Brewer (director); Kenya Barris, Barry W...
# 178         The Father  Florian Zeller (director/screenplay); Christop...
# 179  Wonder Woman 1984  Patty Jenkins (director/screenplay); Geoff Joh...
# 180  News of the World  Paul Greengrass (director/screenplay); Luke Da...
# 181                NaN                                                NaN
#
# [182 rows x 2 columns]

# %%
from tmdbv3api import TMDb
import json
import requests
tmdb = TMDb()
tmdb.api_key = '646c74cb1b97bfe3e9e17a9a8761a61e'

# %%
from tmdbv3api import Movie
tmdb_movie = Movie()
def get_genre(x):
    genres = []
    result = tmdb_movie.search(x)
    movie_id = result[0].id
    response = requests.get('https://api.themoviedb.org/3/movie/{}?api_key={}'.format(movie_id,tmdb.api_key))
    data_json = response.json()
    if data_json['genres']:
        genre_str = " " 
        for i in range(0,len(data_json['genres'])):
            genres.append(data_json['genres'][i]['name'])
        return genre_str.join(genres)
    else:
        np.NaN

# %%
df_2020['genres'] = df_2020['Title'].map(lambda x: get_genre(str(x)))
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
df_2020
# Out:
#                  Title                                      Cast and crew  \
# 0           The Grudge  Nicolas Pesce (director/screenplay); Andrea Ri...
# 1           Underwater  William Eubank (director); Brian Duffield, Ada...
# 2          Like a Boss  Miguel Arteta (director); Sam Pitman, Adam Col...
# 3    Inherit the Viper  Anthony Jerjen (director); Andrew Crabtree (sc...
# 4           The Sonata  Andrew Desmond (director/screenplay); Arthur M...
# ..                 ...                                                ...
# 177   Coming 2 America  Craig Brewer (director); Kenya Barris, Barry W...
# 178         The Father  Florian Zeller (director/screenplay); Christop...
# 179  Wonder Woman 1984  Patty Jenkins (director/screenplay); Geoff Joh...
# 180  News of the World  Paul Greengrass (director/screenplay); Luke Da...
# 181                NaN                                                NaN
#
#                                      genres
# 0                            Horror Mystery
# 1    Action Horror Science Fiction Thriller
# 2                                    Comedy
# 3                      Drama Thriller Crime
# 4                   Horror Thriller Mystery
# ..                                      ...
# 177                                  Comedy
# 178                                   Drama
# 179                Fantasy Action Adventure
# 180                           Drama Western
# 181                                    None
#
# [182 rows x 3 columns]

# %%
def get_director(x):
    if " (director)" in x:
        return x.split(" (director)")[0]
    elif " (directors)" in x:
        return x.split(" (directors)")[0]
    else:
        return x.split(" (director/screenplay)")[0]

# %%
df_2020['director_name'] = df_2020['Cast and crew'].map(lambda x: get_director(str(x)))
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
def get_actor1(x):
    return ((x.split("screenplay); ")[-1]).split(", ")[0])

# %%
df_2020['actor_1_name'] = df_2020['Cast and crew'].map(lambda x: get_actor1(str(x)))
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
def get_actor2(x):
    if len((x.split("screenplay); ")[-1]).split(", ")) < 2:
        return np.NaN
    else:
        return ((x.split("screenplay); ")[-1]).split(", ")[1])

# %%
df_2020['actor_2_name'] = df_2020['Cast and crew'].map(lambda x: get_actor2(str(x)))

# %%
def get_actor3(x):
    if len((x.split("screenplay); ")[-1]).split(", ")) < 3:
        return np.NaN
    else:
        return ((x.split("screenplay); ")[-1]).split(", ")[2])

# %%
df_2020['actor_3_name'] = df_2020['Cast and crew'].map(lambda x: get_actor3(str(x)))

# %%
df_2020
# Out:
#                  Title                                      Cast and crew  \
# 0           The Grudge  Nicolas Pesce (director/screenplay); Andrea Ri...
# 1           Underwater  William Eubank (director); Brian Duffield, Ada...
# 2          Like a Boss  Miguel Arteta (director); Sam Pitman, Adam Col...
# 3    Inherit the Viper  Anthony Jerjen (director); Andrew Crabtree (sc...
# 4           The Sonata  Andrew Desmond (director/screenplay); Arthur M...
# ..                 ...                                                ...
# 177   Coming 2 America  Craig Brewer (director); Kenya Barris, Barry W...
# 178         The Father  Florian Zeller (director/screenplay); Christop...
# 179  Wonder Woman 1984  Patty Jenkins (director/screenplay); Geoff Joh...
# 180  News of the World  Paul Greengrass (director/screenplay); Luke Da...
# 181                NaN                                                NaN
#
#                                      genres    director_name  \
# 0                            Horror Mystery    Nicolas Pesce
# 1    Action Horror Science Fiction Thriller   William Eubank
# 2                                    Comedy    Miguel Arteta
# 3                      Drama Thriller Crime   Anthony Jerjen
# 4                   Horror Thriller Mystery   Andrew Desmond
# ..                                      ...              ...
# 177                                  Comedy     Craig Brewer
# 178                                   Drama   Florian Zeller
# 179                Fantasy Action Adventure    Patty Jenkins
# 180                           Drama Western  Paul Greengrass
# 181                                    None              nan
#
#            actor_1_name       actor_2_name     actor_3_name
# 0    Andrea Riseborough      Demián Bichir         John Cho
# 1       Kristen Stewart     Vincent Cassel  Jessica Henwick
# 2       Tiffany Haddish         Rose Byrne      Salma Hayek
# 3         Josh Hartnett  Margarita Levieva   Chandler Riggs
# 4         Freya Tingley     Simon Abkarian     Rutger Hauer
# ..                  ...                ...              ...
# 177        Eddie Murphy    Jermaine Fowler     Arsenio Hall
# 178     Anthony Hopkins      Olivia Colman      Mark Gatiss
# 179           Gal Gadot         Chris Pine     Kristen Wiig
# 180           Tom Hanks      Helena Zengel  Neil Sandilands
# 181                 nan                NaN              NaN
#
# [182 rows x 7 columns]

# %%
df_2020 = df_2020.rename(columns={'Title':'movie_title'})

# %%
new_df20 = df_2020.loc[:,['director_name','actor_1_name','actor_2_name','actor_3_name','genres','movie_title']]

# %%
new_df20
# Out:
#        director_name        actor_1_name       actor_2_name     actor_3_name  \
# 0      Nicolas Pesce  Andrea Riseborough      Demián Bichir         John Cho
# 1     William Eubank     Kristen Stewart     Vincent Cassel  Jessica Henwick
# 2      Miguel Arteta     Tiffany Haddish         Rose Byrne      Salma Hayek
# 3     Anthony Jerjen       Josh Hartnett  Margarita Levieva   Chandler Riggs
# 4     Andrew Desmond       Freya Tingley     Simon Abkarian     Rutger Hauer
# ..               ...                 ...                ...              ...
# 177     Craig Brewer        Eddie Murphy    Jermaine Fowler     Arsenio Hall
# 178   Florian Zeller     Anthony Hopkins      Olivia Colman      Mark Gatiss
# 179    Patty Jenkins           Gal Gadot         Chris Pine     Kristen Wiig
# 180  Paul Greengrass           Tom Hanks      Helena Zengel  Neil Sandilands
# 181              nan                 nan                NaN              NaN
#
#                                      genres        movie_title
# 0                            Horror Mystery         The Grudge
# 1    Action Horror Science Fiction Thriller         Underwater
# 2                                    Comedy        Like a Boss
# 3                      Drama Thriller Crime  Inherit the Viper
# 4                   Horror Thriller Mystery         The Sonata
# ..                                      ...                ...
# 177                                  Comedy   Coming 2 America
# 178                                   Drama         The Father
# 179                Fantasy Action Adventure  Wonder Woman 1984
# 180                           Drama Western  News of the World
# 181                                    None                NaN
#
# [182 rows x 6 columns]

# %%
new_df20['comb'] = new_df20['actor_1_name'] + ' ' + new_df20['actor_2_name'] + ' '+ new_df20['actor_3_name'] + ' '+ new_df20['director_name'] +' ' + new_df20['genres']

# %%
new_df20.isna().sum()
# Out:
# director_name     0
# actor_1_name      0
# actor_2_name      3
# actor_3_name     14
# genres            2
# movie_title       1
# comb             15
# dtype: int64

# %%
new_df20 = new_df20.dropna(how='any')

# %%
new_df20.isna().sum()
# Out:
# director_name    0
# actor_1_name     0
# actor_2_name     0
# actor_3_name     0
# genres           0
# movie_title      0
# comb             0
# dtype: int64

# %%
new_df20['movie_title'] = new_df20['movie_title'].str.lower()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
new_df20
# Out:
#         director_name        actor_1_name       actor_2_name     actor_3_name  \
# 0       Nicolas Pesce  Andrea Riseborough      Demián Bichir         John Cho
# 1      William Eubank     Kristen Stewart     Vincent Cassel  Jessica Henwick
# 2       Miguel Arteta     Tiffany Haddish         Rose Byrne      Salma Hayek
# 3      Anthony Jerjen       Josh Hartnett  Margarita Levieva   Chandler Riggs
# 4      Andrew Desmond       Freya Tingley     Simon Abkarian     Rutger Hauer
# ..                ...                 ...                ...              ...
# 176  Steven Spielberg        Ansel Elgort      Rachel Zegler    Ariana DeBose
# 177      Craig Brewer        Eddie Murphy    Jermaine Fowler     Arsenio Hall
# 178    Florian Zeller     Anthony Hopkins      Olivia Colman      Mark Gatiss
# 179     Patty Jenkins           Gal Gadot         Chris Pine     Kristen Wiig
# 180   Paul Greengrass           Tom Hanks      Helena Zengel  Neil Sandilands
#
#                                      genres        movie_title  \
# 0                            Horror Mystery         the grudge
# 1    Action Horror Science Fiction Thriller         underwater
# 2                                    Comedy        like a boss
# 3                      Drama Thriller Crime  inherit the viper
# 4                   Horror Thriller Mystery         the sonata
# ..                                      ...                ...
# 176                     Music Crime Romance    west side story
# 177                                  Comedy   coming 2 america
# 178                                   Drama         the father
# 179                Fantasy Action Adventure  wonder woman 1984
# 180                           Drama Western  news of the world
#
#                                                   comb
# 0    Andrea Riseborough Demián Bichir John Cho Nico...
# 1    Kristen Stewart Vincent Cassel Jessica Henwick...
# 2    Tiffany Haddish Rose Byrne Salma Hayek Miguel ...
# 3    Josh Hartnett Margarita Levieva Chandler Riggs...
# 4    Freya Tingley Simon Abkarian Rutger Hauer Andr...
# ..                                                 ...
# 176  Ansel Elgort Rachel Zegler Ariana DeBose Steve...
# 177  Eddie Murphy Jermaine Fowler Arsenio Hall Crai...
# 178  Anthony Hopkins Olivia Colman Mark Gatiss Flor...
# 179  Gal Gadot Chris Pine Kristen Wiig Patty Jenkin...
# 180  Tom Hanks Helena Zengel Neil Sandilands Paul G...
#
# [167 rows x 7 columns]

# %%
old_df = pd.read_csv('final_data.csv')

# %%
old_df
# Out:
#               director_name       actor_1_name          actor_2_name  \
# 0             James Cameron        CCH Pounder      Joel David Moore
# 1            Gore Verbinski        Johnny Depp         Orlando Bloom
# 2                Sam Mendes    Christoph Waltz          Rory Kinnear
# 3         Christopher Nolan          Tom Hardy        Christian Bale
# 4               Doug Walker        Doug Walker            Rob Walker
# ...                     ...                ...                   ...
# 5865           Greta Gerwig      Saoirse Ronan           Emma Watson
# 5866             Sam Mendes      George MacKay  Dean-Charles Chapman
# 5867  Destin Daniel Cretton  Michael B. Jordan            Jamie Foxx
# 5868        Chinonye Chukwu      Alfre Woodard        Wendell Pierce
# 5869           Waymon Boone        Mena Suvari          Kevin Pollak
#
#               actor_3_name                           genres  \
# 0                Wes Studi  Action Adventure Fantasy Sci-Fi
# 1           Jack Davenport         Action Adventure Fantasy
# 2         Stephanie Sigman        Action Adventure Thriller
# 3     Joseph Gordon-Levitt                  Action Thriller
# 4                  unknown                      Documentary
# ...                    ...                              ...
# 5865         Florence Pugh                    Drama Romance
# 5866           Mark Strong         War Drama Action History
# 5867           Brie Larson                      Drama Crime
# 5868           Aldis Hodge                            Drama
# 5869               unknown                  Horror Thriller
#
#                                             movie_title  \
# 0                                                avatar
# 1              pirates of the caribbean: at world's end
# 2                                               spectre
# 3                                 the dark knight rises
# 4     star wars: episode vii - the force awakens    ...
# ...                                                 ...
# 5865                                       little women
# 5866                                               1917
# 5867                                         just mercy
# 5868                                           clemency
# 5869                                         apparition
#
#                                                    comb
# 0     CCH Pounder Joel David Moore Wes Studi James C...
# 1     Johnny Depp Orlando Bloom Jack Davenport Gore ...
# 2     Christoph Waltz Rory Kinnear Stephanie Sigman ...
# 3     Tom Hardy Christian Bale Joseph Gordon-Levitt ...
# 4     Doug Walker Rob Walker unknown Doug Walker Doc...
# ...                                                 ...
# 5865  Saoirse Ronan Emma Watson Florence Pugh Greta ...
# 5866  George MacKay Dean-Charles Chapman Mark Strong...
# 5867  Michael B. Jordan Jamie Foxx Brie Larson Desti...
# 5868  Alfre Woodard Wendell Pierce Aldis Hodge Chino...
# 5869  Mena Suvari Kevin Pollak unknown Waymon Boone ...
#
# [5870 rows x 7 columns]

# %%
final_df = old_df.append(new_df20,ignore_index=True)

# %%
final_df
# Out:
#           director_name     actor_1_name      actor_2_name  \
# 0         James Cameron      CCH Pounder  Joel David Moore
# 1        Gore Verbinski      Johnny Depp     Orlando Bloom
# 2            Sam Mendes  Christoph Waltz      Rory Kinnear
# 3     Christopher Nolan        Tom Hardy    Christian Bale
# 4           Doug Walker      Doug Walker        Rob Walker
# ...                 ...              ...               ...
# 6032   Steven Spielberg     Ansel Elgort     Rachel Zegler
# 6033       Craig Brewer     Eddie Murphy   Jermaine Fowler
# 6034     Florian Zeller  Anthony Hopkins     Olivia Colman
# 6035      Patty Jenkins        Gal Gadot        Chris Pine
# 6036    Paul Greengrass        Tom Hanks     Helena Zengel
#
#               actor_3_name                           genres  \
# 0                Wes Studi  Action Adventure Fantasy Sci-Fi
# 1           Jack Davenport         Action Adventure Fantasy
# 2         Stephanie Sigman        Action Adventure Thriller
# 3     Joseph Gordon-Levitt                  Action Thriller
# 4                  unknown                      Documentary
# ...                    ...                              ...
# 6032         Ariana DeBose              Music Crime Romance
# 6033          Arsenio Hall                           Comedy
# 6034           Mark Gatiss                            Drama
# 6035          Kristen Wiig         Fantasy Action Adventure
# 6036       Neil Sandilands                    Drama Western
#
#                                             movie_title  \
# 0                                                avatar
# 1              pirates of the caribbean: at world's end
# 2                                               spectre
# 3                                 the dark knight rises
# 4     star wars: episode vii - the force awakens    ...
# ...                                                 ...
# 6032                                    west side story
# 6033                                   coming 2 america
# 6034                                         the father
# 6035                                  wonder woman 1984
# 6036                                  news of the world
#
#                                                    comb
# 0     CCH Pounder Joel David Moore Wes Studi James C...
# 1     Johnny Depp Orlando Bloom Jack Davenport Gore ...
# 2     Christoph Waltz Rory Kinnear Stephanie Sigman ...
# 3     Tom Hardy Christian Bale Joseph Gordon-Levitt ...
# 4     Doug Walker Rob Walker unknown Doug Walker Doc...
# ...                                                 ...
# 6032  Ansel Elgort Rachel Zegler Ariana DeBose Steve...
# 6033  Eddie Murphy Jermaine Fowler Arsenio Hall Crai...
# 6034  Anthony Hopkins Olivia Colman Mark Gatiss Flor...
# 6035  Gal Gadot Chris Pine Kristen Wiig Patty Jenkin...
# 6036  Tom Hanks Helena Zengel Neil Sandilands Paul G...
#
# [6037 rows x 7 columns]

# %%
final_df.to_csv('main_data.csv',index=False)

# %%
final_df.isnull().sum()
# Out:
# director_name    0
# actor_1_name     0
# actor_2_name     0
# actor_3_name     0
# genres           0
# movie_title      0
# comb             0
# dtype: int64
